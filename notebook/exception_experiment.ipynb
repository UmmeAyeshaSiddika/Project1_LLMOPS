# %%
print("all ok")
# Out:
# all ok

# %%
### __file__ in .py file automatically gets the name of the file

# %%
logger=CustomLogger().get_logger("exception_experiment")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 logger=CustomLogger().get_logger("exception_experiment")
#
# NameError: name 'CustomLogger' is not defined

# %%
import sys
import traceback

# %%
import sys
import traceback
class DocumentPortalException(Exception):
    """Custom exception for Project1_LLMOPS"""
    def __init__(self,error_message,error_details:sys):
        print(error_details.exc_info())
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info())) 
    def __str__(self):
       return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback:
        {self.traceback_str}
        """
    
if __name__ == "__main__":
    try:
        # Simulate an error
        a = 1 / 0
        print(a)
    except Exception as e:
        app_exc=DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x00000270CCCBA3C0>)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 27
#      25     except Exception as e:
#      26         app_exc=DocumentPortalException(e,sys)
# ---> 27         logger.error(app_exc)
#      28         raise app_exc
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 27
#      23         a = 1 / 0
#      24         print(a)
#      25     except Exception as e:
#      26         app_exc=DocumentPortalException(e,sys)
# ---> 27         logger.error(app_exc)
#      28         raise app_exc
#
# NameError: name 'logger' is not defined

# %%
#1. log this error(file, cloud config, command prompt) (it will keep the record of the error and will not stop the execution of the code)
#2. raise the exception(it will stop the execution of the code)

# %%
#(<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x00000231341AAD40>)

# %%
import sys
sys.exc_info()
# Out:
# (None, None, None)

# %%
a,b,c=(1,2,3)

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3
